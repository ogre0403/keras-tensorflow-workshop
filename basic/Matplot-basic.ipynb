# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([1,2,3,4])

# %%
plt.plot([1,2,3,4],[1,4,9,16])
plt.ylabel('y label')
plt.xlabel('x label')
# Out:
# Text(0.5,0,'x label')

# %%
plt.plot([1,2,3,4],[1,4,9,16],'ro')
plt.ylabel('y label')
plt.xlabel('x label')
# Out:
# Text(0.5,0,'x label')

# %%
t = np.arange(0., 5., 0.2)
plt.plot(t,t,'r--', t,t**2,'bs', t, t**3,'g^')

# %%
x = [4,5,7,7,7,8,9,10,10,11]
y = [2,3,5,6,2,5,1,1,2,2]

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 10 artists>

# %%
plt.scatter(x,y)
